# %%
pywt.families()
# Out:
# ['haar',
#  'db',
#  'sym',
#  'coif',
#  'bior',
#  'rbio',
#  'dmey',
#  'gaus',
#  'mexh',
#  'morl',
#  'cgau',
#  'shan',
#  'fbsp',
#  'cmor']

# %%
pywt.families(short=False)
# Out:
# ['Haar',
#  'Daubechies',
#  'Symlets',
#  'Coiflets',
#  'Biorthogonal',
#  'Reverse biorthogonal',
#  'Discrete Meyer (FIR Approximation)',
#  'Gaussian',
#  'Mexican hat wavelet',
#  'Morlet wavelet',
#  'Complex Gaussian wavelets',
#  'Shannon wavelets',
#  'Frequency B-Spline wavelets',
#  'Complex Morlet wavelets']

# %%
import pywt
import pywt.data
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [15, 7]

x = pywt.data.ecg()
#plt.plot(x)
#plt.legend(['Original signal'])

# %%
y=np.array(x).reshape(32,32)

# %%
coeffs = pywt.dwt2(y, 'haar')
cA, (cH, cV, cD) = coeffs
x2=cA.flatten()

# %%
plt.plot(x)
#plt.plot(x2)

# %%
plt.plot(x2)

# %%
coeffs = pywt.dwt2(cA, 'haar')
cA2, (cH, cV, cD) = coeffs
plt.plot(cA2.flatten())
